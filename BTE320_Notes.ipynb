# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasNavarro11/BTE320/blob/main/BTE320_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('print')
# Out:
# print
