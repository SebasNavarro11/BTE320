# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasNavarro11/BTE320/blob/main/BTE320_Notes_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=2

# %% [markdown]
# The x represents the 2

# %%
x==2
# Out:
# True

# %% [markdown]
# Mathematically equal to x=2, it can only be true or false

# %%
s='abc'

# %%
a=3
b=5
a==b
a<b
a<=b
a>b
a>=b
a!=b

# %% [markdown]
# Operators to know

# %%
8+3
# Out:
# 11

# %%
6-3
# Out:
# 3

# %%
4*3
# Out:
# 12

# %%
6/4
# Out:
# 1.5

# %% [markdown]
# normal divison makes floats (decimals)

# %%
6//4
# Out:
# 1

# %% [markdown]
# double slash removes decimal, does not round

# %% [markdown]
# if one of the values is a float (decimal), the output will be a float, but ending in .0

# %%
2**3
# Out:
# 8

# %% [markdown]
# double ** makes it to the power of

# %%
5%3
# Out:
# 2

# %% [markdown]
# Remainder of the divison, after 3 goes into 5 there are 2 remaining

# %%
6%3
# Out:
# 0

# %% [markdown]
# there is no remainder because 3 goes into 6 2 times without any leftover

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %% [markdown]
# with the AND, all items have to be true for the operator to be true, if one is false, everything is false

# %%
True or Flase
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# In OR operators, all objects have to be false for the whole operator to be false, if one is true, everything will be true

# %%
x=x+1

# %% [markdown]
# Expression that updates the "x" value. If x had been previously assiged 1, then the new expression would mean that x=1+1, therefore updating it to a value of 2

# %%
x+=1

# %% [markdown]
# same thing as the expression above, but abbribiated

# %%
3 in ...
3 not in ...

# %% [markdown]
# FInd whether or not the object is in or is not in a certain list, true or false output

# %%
name=5
name4=6
4name=7
name_5=8
name 6=9

# %% [markdown]
# Names can be a combination of any amount of numbers and letters, as long as they dont start with a number or have any gaps. An underscore can be used. The first 2 names are valid the third one is not.

# %%
type(x)
# Out:
# int

# %% [markdown]
# gives you the type of the object within the parenthesis

# %%
isinstance(x,float)
# Out:
# False

# %% [markdown]
# gives you a true of false statement, boolean

# %%
a = 3
b = 'abc'

# %%
a, b = 3, 'abc'
