# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasNavarro11/BTE320/blob/main/In_class_assignment_bte320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales ($): "))
rate = float(input("Enter tax rate (%): "))

cogs = (sales * 0.4)
gross = sales - cogs
taxes = rate * gross
net = gross - taxes

print(f"Sales: ${sales}")
print(f"Cost of Good Sold: ${cogs}")
print(f"Gross Profit: ${gross}")
print(f"Taxes: ${taxes}")
print(f"Net income: ${net}")
# Out:
# Enter sales ($): 12000
# Enter tax rate (%): 3
# Sales: $12000.0
# Cost of Good Sold: $4800.0
# Gross Profit: $7200.0
# Taxes: $21600.0
# Net income: $-14400.0

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Choose numerical operator: ")

if op == "+":
  res = num1 + num2
elif op == "-":
  res = num1 - num2
elif op == "*":
  res = num1 * num2
elif op == "/":
  res = num1 / num2
elif op == "//":
  res = num1 // num2
elif op == "**":
  res = num1 ** num2
elif op == "%":
  res = num1 % num2
else:
  print("Invalid operation")
  res = None

print(f"Result: {res}")
# Out:
# Enter first number: 3
# Enter second number: 5
# Choose numerical operator: *
# Result: 15.0

# %%
import math

ticket = 10
init_attendees = 20
fixed_cost = 200

for ad in range(0, 201, 25):
  revenue = (init_attendees + 2 * round(math.sqrt(ad))) * 10
  costs = fixed_cost + ad
  profit = revenue - costs
  print(ad, profit)

# %% [markdown]
# continue

# %%
for hour in range (1, 9):
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(fee)
# Out:
# 10.0
# 10.0
# 12.5
# 15.0
# 17.5
# 20.0
# 20.0
# 20.0

# %%
def calcFee(hour):
  fee = 5 + 2.5 * hour
  if fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(fee)

def main():
  hour = int(input('Enter number of hours parked: '))
  calcFee(hour)

main()
# Out:
# Enter number of hours parked: 5
# 17.5

# %%
def reverse(s):
  if len(s) < 2:
    return s
  else:
    #return s[-1] + reverse(s[:-1]) #Take the last char and put it first
    #return reverse(s[1:]) + s[0] #Take the first character and put it last
    return s[-1] + reverse(s[1:-1]) + s[0]

reverse('12345')
# Out:
# '54321'
